# %% [markdown]
# <a href="https://colab.research.google.com/github/sugumaranj/Python-For-Data-Analysis-Internship/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Practise 1 : Product Sales Performance Analysis

# %%
import numpy as np
products = ["Laptop", "Mobile", "Tablet", "Headphone", "Smartwatch"]

# Sales units
sales = np.array([120, 250, 80, 150, 100])

# Total sales
print("Total Sales:", np.sum(sales))

# Average sales
print("Average Sales:", np.mean(sales))

# Highest sales
print("Highest Sales:", np.max(sales))

# Lowest sales
print("Lowest Sales:", np.min(sales))

# Best-selling product
best_index = np.argmax(sales)
print("Best Selling Product:", products[best_index])

# Product-wise sales
print("\nProduct Sales Report")
print("-"*30)
for i in range(len(products)):
    print(products[i], ":", sales[i])
# Out:
# Total Sales: 700
# Average Sales: 140.0
# Highest Sales: 250
# Lowest Sales: 80
# Best Selling Product: Mobile
#
# Product Sales Report
# ------------------------------
# Laptop : 120
# Mobile : 250
# Tablet : 80
# Headphone : 150
# Smartwatch : 100
